# %% [markdown]
# # 🚀 AI Project: User Segmentation & CTR Prediction using Random Variables
# # Simulating different user types and comparing click behavior

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Step 1: Define User Segments

# %%
# Different user types with different click behavior
segments = {    "casual_users": {0: 0.7, 1: 0.2, 2: 0.1},   
                "regular_users": {0: 0.4, 1: 0.4, 2: 0.2},    
                "power_users": {0: 0.2, 1: 0.5, 2: 0.3}}

# %% [markdown]
# ## Step 2: Simulate User Sessions

# %%
simulation_results = {}
for segment, pmf in segments.items():    
    values = list(pmf.keys())    
    probs = list(pmf.values())    
    simulated = np.random.choice(values, size=1000, p=probs)    
    simulation_results[segment] = simulated
print(simulation_results.keys())
# Out:
# dict_keys(['casual_users', 'regular_users', 'power_users'])

# %% [markdown]
# ## Step 3: Compute Expected Clicks (CTR Proxy)

# %%
expected_clicks = {}
for segment, data in simulation_results.items():    
    expected_clicks[segment] = np.mean(data)
print(expected_clicks)
# Out:
# {'casual_users': np.float64(0.43), 'regular_users': np.float64(0.768), 'power_users': np.float64(1.133)}

# %% [markdown]
# ## Step 4: Compare Segments

# %%
df = pd.DataFrame({"segment": list(expected_clicks.keys()),    
                   "avg_clicks": list(expected_clicks.values())})
df
# Out:
#          segment  avg_clicks
# 0   casual_users       0.430
# 1  regular_users       0.768
# 2    power_users       1.133

# %% [markdown]
# ## Step 5: Visualize CTR Comparison

# %%
plt.bar(df['segment'], df['avg_clicks'])
plt.xlabel('User Segment')
plt.ylabel('Average Clicks (CTR)')
plt.title('CTR Comparison Across User Segments')
plt.show()

# %% [markdown]
# ## Step 6: Distribution per Segment

# %%
for segment, data in simulation_results.items():    
    unique, counts = np.unique(data, return_counts=True)    
    plt.bar(unique, counts/len(data))    
    plt.title(f'PMF - {segment}')    
    plt.xlabel('Clicks')    
    plt.ylabel('Probability')    
    plt.show()

# %% [markdown]
# ## 💡 Insights- Power users have higher CTR- Casual users rarely click- Useful for ad targeting & personalization
